# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
import os
import shutil
from sklearn.metrics import accuracy_score

# %matplotlib inline
seed = 0
np.random.seed(seed)

tf.random.set_seed(seed)

os.environ['PATH'] = os.environ['XILINX_VITIS'] + '/bin:' + os.environ['PATH']
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778322628.974046  994043 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
X_test = X_test.astype("float32") / 255
y_test = keras.utils.to_categorical(y_test, 10)

# %%
from keras.models import load_model

model = load_model('baseline/MNIST_baseline_model.keras')
score = model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9913 - loss: 0.0262

# %%
import hls4ml

output_dir ="baseline/hls4ml_prj_MNIST_baseline_iostream"
if os.path.exists(output_dir):
    shutil.rmtree(output_dir)
    
hls_config = hls4ml.utils.config_from_keras_model(model, granularity='name')

#hls_config['Model']['Strategy'] = 'Distributed Arithmetic'
#proj_name = f"{str(model_to_test)}_{str(model_revision)}_hls4ml_prj_{str(hls4ml_revision)}"

hls_model = hls4ml.converters.convert_from_keras_model(
    model,    
    backend='vitisunified',
    hls_config=hls_config,
    io_type='io_stream',
    #proj_name = proj_name,
    output_dir=output_dir, 
    board       = 'kv260',
    part='xck26-sfvc784-2LV-c',
    clock_period='5',
)
hls_model.compile()

# %%
hls_model.build(csim=False, synth=True, cosim=False)
# Out:
# ****** v++ v2025.2 (64-bit)
#   **** SW Build 6295257 on 2025-11-13-01:29:13
#   **** Start of session at: Mon Apr 27 15:45:34 2026
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2025 Advanced Micro Devices, Inc. All Rights Reserved.
#
#   **** HLS Build v2025.2 6295257
# INFO: [HLS 200-2005] Using work_dir /home/ncgadmin/DAT255/DAT255-project/MNIST/MNIST_baseline/HLS4ML_MNIST_baseline/vitis_workspace/myproject/vitis_unified_project
# INFO: [HLS 200-2176] Writing Vitis IDE component file /home/ncgadmin/DAT255/DAT255-project/MNIST/MNIST_baseline/HLS4ML_MNIST_baseline/vitis_workspace/myproject/vitis_unified_project/vitis-comp.json
# INFO: [HLS 200-10] Creating and opening component '/home/ncgadmin/DAT255/DAT255-project/MNIST/MNIST_baseline/HLS4ML_MNIST_baseline/vitis_workspace/myproject/vitis_unified_project'.
# INFO: [HLS 200-1505] Using default flow_target 'vivado'
# ...

# %%
y_baseline = model.predict(X_test)
np.save("y_baseline.npy",y_baseline)
# Out:
#  40/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
